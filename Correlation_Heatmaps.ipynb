# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Structured Data/panel.csv')
data
# Out:
#              id               Constituency  Year  voteShare      pm2.5  \
# 0     E14000530                  ALDERSHOT  2015   4.383971   8.846666
# 1     E14000530                  ALDERSHOT  2017   2.226762  10.082955
# 2     E14000530                  ALDERSHOT  2019   3.651006   9.274174
# 3     E14000531        ALDRIDGE-BROWNHILLS  2010   2.192369  11.981145
# 4     E14000531        ALDRIDGE-BROWNHILLS  2015   2.091298   9.866992
# ...         ...                        ...   ...        ...        ...
# 1848  W07000079               CARDIFF WEST  2019   2.453602   7.950449
# 1849  W07000080  CARDIFF SOUTH AND PENARTH  2010   1.248620  10.672662
# 1850  W07000080    CARDIFF SOUTH & PENARTH  2015   3.741402   9.057560
# 1851  W07000080  CARDIFF SOUTH AND PENARTH  2017   1.048565   8.169903
# 1852  W07000080  CARDIFF SOUTH AND PENARTH  2019   2.336938   8.160664
#
#             no2       pm10       so2        oz  percHighEdu  medianAge  \
# 0     12.796069  13.094674  1.141398  2.390224    26.242236       38.0
# 1     13.942493  14.306478  1.210831  2.623056    41.945289       38.3
# 2     13.384457  13.830559  1.405279  8.998642    33.432836       39.2
# 3     24.692361  16.807375  4.611836  1.052704    21.126761       43.9
# 4     16.429376  14.784795  1.762224  1.257560    25.675676       45.4
# ...         ...        ...       ...       ...          ...        ...
# 1848  12.344978  12.615806  1.502710  4.104544    39.874411       37.5
# 1849  23.442608  15.095450  4.410538  1.021191    36.621824       35.1
# 1850  16.121387  13.552206  2.576069  1.573032    37.943696       35.0
# 1851  14.556137  12.135514  2.660229  1.449698    42.245989       35.0
# 1852  13.423341  12.784938  1.943629  4.209962    47.120419       35.1
#
#        popDensity
# 0     1991.990809
# 1     2004.467650
# 2     1986.063838
# 3     1702.291600
# 4     1763.972948
# ...           ...
# 1848  1847.267401
# 1849  2200.790787
# 1850  2359.009936
# 1851  2408.896976
# 1852  2456.174862
#
# [1853 rows x 12 columns]

# %%
numeric_cols = ['pm2.5', 'no2', 'pm10', 'so2', 'oz', 'percHighEdu', 'medianAge', 'voteShare']
numeric_data = data[numeric_cols]
numeric_data.hist(figsize=(10,10),color='black',grid=False)
#plt.axis(False)
plt.show()

# %%
corr = data[numeric_data.columns].corr()
f, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(corr, center=0,cmap=plt.get_cmap('viridis'),
            square=True, linewidths=.05, annot=True, vmin=-1, vmax=1,ax=ax) 
plt.show()

# %%
count = (data['voteShare'] > 50).sum()
count
# Out:
# 2

# %%
dataNoSkew = data.drop(data[data['voteShare'] > 20].index)
