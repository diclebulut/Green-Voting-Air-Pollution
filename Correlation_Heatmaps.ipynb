# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Structured Data/panel.csv')
data
# Out:
#              id               Constituency  Year  voteShare      pm2.5  \
# 0     E14000530                  ALDERSHOT  2015   4.383971   8.846666
# 1     E14000530                  ALDERSHOT  2017   2.226762  10.082955
# 2     E14000530                  ALDERSHOT  2019   3.651006   9.274174
# 3     E14000531        ALDRIDGE-BROWNHILLS  2010   2.192369  11.981145
# 4     E14000531        ALDRIDGE-BROWNHILLS  2015   2.091298   9.866992
# ...         ...                        ...   ...        ...        ...
# 1722  W07000079               CARDIFF WEST  2019   2.453602   7.950449
# 1723  W07000080  CARDIFF SOUTH AND PENARTH  2010   1.248620  10.672662
# 1724  W07000080    CARDIFF SOUTH & PENARTH  2015   3.741402   9.057560
# 1725  W07000080  CARDIFF SOUTH AND PENARTH  2017   1.048565   8.169903
# 1726  W07000080  CARDIFF SOUTH AND PENARTH  2019   2.336938   8.160664
#
#             no2       pm10  percHighEdu  medianIncome
# 0     12.796069  13.094674    26.242236         28210
# 1     13.942493  14.306478    41.945289         29486
# 2     13.384457  13.830559    33.432836         32228
# 3     24.692361  16.807375    21.126761         25751
# 4     16.429376  14.784795    25.675676         25749
# ...         ...        ...          ...           ...
# 1722  12.344978  12.615806    39.874411         29146
# 1723  23.442608  15.095450    36.621824         24821
# 1724  16.121387  13.552206    37.943696         24253
# 1725  14.556137  12.135514    42.245989         26321
# 1726  13.423341  12.784938    47.120419         29027
#
# [1727 rows x 9 columns]

# %%
numeric_cols = ['pm2.5', 'no2', 'pm10', 'percHighEdu', 'medianIncome', 'voteShare']
numeric_data = dataNoSkew[numeric_cols]
numeric_data.hist(figsize=(10,10),color='black',grid=False)
#plt.axis(False)
plt.show()

# %%
corr = data[numeric_data.columns].corr()
f, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(corr, center=0,cmap=plt.get_cmap('viridis'),
            square=True, linewidths=.05, annot=True, vmin=-1, vmax=1,ax=ax) 
plt.show()

# %%
count = (data['voteShare'] > 50).sum()
count
# Out:
# 2

# %%
dataNoSkew = data.drop(data[data['voteShare'] > 20].index)
